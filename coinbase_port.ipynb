# %%
# Crypto Portfolio Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
import requests

# %%
df = pd.read_csv('account.csv')
df.drop(columns = ['transfer id', 'trade id', 'order id'], inplace = True)
df.head()
# Out:
#   portfolio        type                      time    amount       balance  \
# 0   default       match  2021-01-02T05:35:42.191Z  0.600000  6.000000e-01
# 1   default       match  2021-01-02T05:35:42.200Z  0.410318  1.010318e+00
# 2   default  withdrawal  2021-01-02T05:45:39.267Z -0.100007  9.103114e-01
# 3   default  withdrawal  2021-01-02T06:25:44.606Z -0.910311  1.000000e-08
# 4   default     deposit  2021-01-08T19:41:46.786Z  0.198794  1.987943e-01
#
#   amount/balance unit
# 0                 BTC
# 1                 BTC
# 2                 BTC
# 3                 BTC
# 4                 BTC

# %%
df = df[df.type == 'match']

# %%
df.head(10)
# Out:
#    portfolio   type                      time    amount   balance  \
# 0    default  match  2021-01-02T05:35:42.191Z  0.600000  0.600000
# 1    default  match  2021-01-02T05:35:42.200Z  0.410318  1.010318
# 5    default  match  2021-01-10T15:58:54.503Z -0.032112  0.166683
# 6    default  match  2021-01-10T15:58:54.507Z -0.025082  0.141601
# 7    default  match  2021-01-10T15:58:54.511Z -0.141601  0.000000
# 9    default  match  2021-01-18T00:02:49.606Z -0.069802  0.139612
# 10   default  match  2021-01-18T00:02:49.611Z -0.040576  0.099036
# 11   default  match  2021-01-18T00:02:49.615Z -0.099036  0.000000
# 12   default  match  2021-02-03T14:07:02.988Z  0.019524  0.019524
# 13   default  match  2021-02-03T14:07:02.993Z  0.252448  0.271972
#
#    amount/balance unit
# 0                  BTC
# 1                  BTC
# 5                  BTC
# 6                  BTC
# 7                  BTC
# 9                  BTC
# 10                 BTC
# 11                 BTC
# ...

# %%
df.drop(columns = ['portfolio'], inplace = True)
df
# Out:
#      type                      time    amount   balance amount/balance unit
# 0   match  2021-01-02T05:35:42.191Z  0.600000  0.600000                 BTC
# 1   match  2021-01-02T05:35:42.200Z  0.410318  1.010318                 BTC
# 5   match  2021-01-10T15:58:54.503Z -0.032112  0.166683                 BTC
# 6   match  2021-01-10T15:58:54.507Z -0.025082  0.141601                 BTC
# 7   match  2021-01-10T15:58:54.511Z -0.141601  0.000000                 BTC
# 9   match  2021-01-18T00:02:49.606Z -0.069802  0.139612                 BTC
# 10  match  2021-01-18T00:02:49.611Z -0.040576  0.099036                 BTC
# 11  match  2021-01-18T00:02:49.615Z -0.099036  0.000000                 BTC
# 12  match  2021-02-03T14:07:02.988Z  0.019524  0.019524                 BTC
# 13  match  2021-02-03T14:07:02.993Z  0.252448  0.271972                 BTC
# 14  match  2021-02-04T15:13:08.430Z -0.038248  0.233724                 BTC
# ...
